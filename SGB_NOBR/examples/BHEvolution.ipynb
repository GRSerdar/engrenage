# %%
#SCALAR GAUSS BONNET MODIFIED EXAMPLE

# Isotropic Schwarzschild BH example
# see further details in https://github.com/GRChombo/engrenage/wiki/Running-the-black-hole-example

# restart the kernel to clear past work
# (can also do this manually from the Kernel options above)
from IPython.core.display import HTML
HTML("<script>Jupyter.notebook.kernel.restart()</script>")
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
# load the required python modules
import numpy as np
from scipy.interpolate import interp1d
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import time
import sys
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

# homemade source code from source folder
sys.path.append('/Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source')

from initialdata.bhinitialconditions import *
from backgrounds.sphericalbackground import *
from bssn.constraintsdiagnostic import *
from bssn.ahfinder import *
from core.rhsevolution import *
from core.grid import Grid
from core.spacing import *
from core.display import *
from core.statevector import *
from matter.scalarmatter import *

# %%
# Set up the chosen matter class
#scalar_mu = 1.0
scalar_mu = 0 # in the EsGB case
my_matter = ScalarMatter(scalar_mu)
my_state_vector = StateVector(my_matter)

# Input parameters for grid and evolution here
r_max = 96.0 # outer edge of the grid (including ghosts)
#min_dr = 1 / 16 # roughly 32 points across the BH

min_dr = 1/16
#min_dr = 1 / 64
max_dr = 2

# SinhSpacing
# params = SinhSpacing.get_parameters(r_max, min_dr, max_dr)
# spacing = SinhSpacing(**params)

# CubicSpacing
params = CubicSpacing.get_parameters(r_max, min_dr, max_dr)
spacing = CubicSpacing(**params)

grid = Grid(spacing, my_state_vector)
r = grid.r
num_points = r.size
background = FlatSphericalBackground(r)

# Check grid params
print(params)
# Out:
# {'r_max': 96.0, 'extent': <SpacingExtent.HALF: 0>, 'a': 1.5213625583444466, 'num_points': 140}

# %%
initial_state = get_initial_state(grid, background)

#unpackage the vector for readability
(initial_phi, initial_hrr, initial_htt, initial_hpp, 
 initial_K, initial_arr, initial_att, initial_app, 
 initial_lambdar, initial_shiftr, initial_br, initial_lapse, 
 initial_u, initial_v) = np.array_split(initial_state, grid.NUM_VARS)

# %%
'''# check the Hamiltonian and momentum constraints are initially satisfied
Ham, Mom = get_constraints_diagnostic(initial_state, np.array([0]), grid, background, my_matter)

# plot the profile for Ham
#plt.plot(r, Ham[0])
plt.plot(r, Mom[0])

plt.xlabel('r')
plt.ylabel('Ham value')
ax = plt.gcf().gca()
set_grid_on_ax(ax, r)
plt.xlim(-0.5,10)
plt.ylim(-0.1,0.1)'''
# Out:
# "# check the Hamiltonian and momentum constraints are initially satisfied\nHam, Mom = get_constraints_diagnostic(initial_state, np.array([0]), grid, background, my_matter)\n\n# plot the profile for Ham\n#plt.plot(r, Ham[0])\nplt.plot(r, Mom[0])\n\nplt.xlabel('r')\nplt.ylabel('Ham value')\nax = plt.gcf().gca()\nset_grid_on_ax(ax, r)\nplt.xlim(-0.5,10)\nplt.ylim(-0.1,0.1)"

# %%
# Check that for a higher resolution the Ham constraint converges (the Mom constraint is trivially zero)

# Input parameters for HR grid
min_dr_HR = 1 / 32 # roughly 64 points across the BH
max_dr_HR = 1

# CubicSpacing
params_HR = CubicSpacing.get_parameters(r_max, min_dr_HR, max_dr_HR)
spacing_HR = CubicSpacing(**params_HR)

grid_HR = Grid(spacing_HR, my_state_vector)
r_HR = grid_HR.r
num_points_HR = r_HR.size
background_HR = FlatSphericalBackground(r_HR)

# Check grid params
print(params_HR)

# Get initial state
initial_state_HR = get_initial_state(grid_HR, background_HR)
# Out:
# {'r_max': 96.0, 'extent': <SpacingExtent.HALF: 0>, 'a': 1.5213625583444466, 'num_points': 275}

# %%
# find the apparent horizon for a given set of states
omega, ah_radius, bh_mass = get_horizon_diagnostics(initial_state, np.array([0]), grid, background, my_matter)

print("horizon is at r =", round(ah_radius[0],1))
print("horizon is at r =", ah_radius[0])
# Out:
# horizon is at r = 0.5
# horizon is at r = 0.498678538330956

# %% [markdown]
# # Start running the simulation

# %%
# for control of time integrator and spatial grid
#T = 10 # Maximum evolution time
T = 70
#num_points_t = 128 # time resolution (only for outputs, not for integration, which is decided by python)
num_points_t = 250

# Work out dt and time spacing of outputs
dt = T/num_points_t
t = np.linspace(0, T-dt, num_points_t)

# Solve for the solution using RK45 integration of the ODE
# to make like (older) python odeint method use method='LSODA' instead
# use tqdm package to track progress
with tqdm(total=1000, unit="‰") as progress_bar:
    dense_solution = solve_ivp(get_rhs, [0,T], initial_state, 
                               args=(grid, background, my_matter, progress_bar, [0, T/1000]),
                        #atol=1e-5, rtol=1e-5,
                        max_step = 0.4 * min_dr, #for stability and for KO coeff of 1
                        method='RK45', dense_output=True)

# Interpolate the solution at the time points requested
solution = dense_solution.sol(t).T
# Out:
#   0%|          | 0/1000 [00:00<?, ?‰/s]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:64: RuntimeWarning: invalid value encountered in power
#   rescaling_factor = np.power(determinant_bar_gamma / determinant_hat_gamma, -1./3)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:207: RuntimeWarning: overflow encountered in multiply
#   TraceFree_S_GB_LL = (- two_thirds * TraceFree_Omega_LL*(F[:,np.newaxis, np.newaxis] + 2 * (ilapse[:,np.newaxis, np.newaxis] * D2_lapse[:,np.newaxis, np.newaxis] - Asquared[:,np.newaxis, np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:208: RuntimeWarning: overflow encountered in multiply
#   - 2 * TraceFree_M_LL*(  Trace_Omega[:,np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:211: RuntimeWarning: overflow encountered in multiply
#   - two_thirds * Trace_Omega[:,np.newaxis, np.newaxis]*(F_LL - one_third * gamma_LL*(ilapse[:,np.newaxis, np.newaxis] * D2_lapse[:,np.newaxis, np.newaxis] - Asquared[:,np.newaxis, np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:207: RuntimeWarning: invalid value encountered in subtract
#   TraceFree_S_GB_LL = (- two_thirds * TraceFree_Omega_LL*(F[:,np.newaxis, np.newaxis] + 2 * (ilapse[:,np.newaxis, np.newaxis] * D2_lapse[:,np.newaxis, np.newaxis] - Asquared[:,np.newaxis, np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:224: RuntimeWarning: overflow encountered in multiply
#   - 8 * (d1_Lambda_d1_u(lambda_GB)[:,np.newaxis, np.newaxis] * d1_Lambda_d1_u(lambda_GB)[:,np.newaxis, np.newaxis] * TraceFree_M_LL * L_GB[:,np.newaxis, np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:73: RuntimeWarning: overflow encountered in exp
#   em4phi = np.exp(-4.0*bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:76: RuntimeWarning: invalid value encountered in multiply
#   gamma_UU = em4phi[:,np.newaxis,np.newaxis] *bar_gamma_UU
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:242: RuntimeWarning: overflow encountered in exp
#   em4phi = np.exp(-4.0 * bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:54: RuntimeWarning: overflow encountered in exp
#   em4phi = np.exp(-4.0 * bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:29: RuntimeWarning: overflow encountered in exp
#   em4phi = np.exp(-4.0* bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:77: RuntimeWarning: overflow encountered in exp
#   chi = np.exp(-4.0* bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/bssnrhs.py:23: RuntimeWarning: overflow encountered in exp
#   em4phi = np.exp(-4.0*bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:291: RuntimeWarning: overflow encountered in exp
#   em4phi = np.exp(-4.0*bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:311: RuntimeWarning: overflow encountered in exp
#   chi = np.exp(-4.0* bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:316: RuntimeWarning: overflow encountered in exp
#   chi = np.exp(-4.0* bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:172: RuntimeWarning: overflow encountered in exp
#   sigma = 1.0 * bssn_vars.lapse * np.exp(-2.0*bssn_vars.phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:243: RuntimeWarning: divide by zero encountered in divide
#   e4phi = 1/em4phi
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:55: RuntimeWarning: divide by zero encountered in divide
#   e4phi = 1/em4phi
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:65: RuntimeWarning: invalid value encountered in multiply
#   gamma_LL = e4phi[:,np.newaxis,np.newaxis] * bar_gamma_LL
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:30: RuntimeWarning: divide by zero encountered in divide
#   e4phi = 1/em4phi
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:43: RuntimeWarning: invalid value encountered in multiply
#   gamma_LL = e4phi[:,np.newaxis,np.newaxis] * bar_gamma_LL
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:87: RuntimeWarning: invalid value encountered in multiply
#   + e4phi[:, np.newaxis, np.newaxis] *(two_nine * bar_gamma_LL* bssn_vars.K[:, np.newaxis, np.newaxis] * bssn_vars.K[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:165: RuntimeWarning: invalid value encountered in multiply
#   D_L_A_LL = e4phi[:, np.newaxis, np.newaxis, np.newaxis]*(  a_times_d1_s
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:150: RuntimeWarning: invalid value encountered in multiply
#   Omega_LL = ( 4 * d1_Lambda_d1_u(lambda_GB)[:,np.newaxis, np.newaxis] * (DiDj_u + e4phi[:,np.newaxis,np.newaxis] * self.v[:,np.newaxis,np.newaxis] * (bar_A_LL + bar_gamma_LL * one_third * bssn_vars.K[:,np.newaxis,np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:176: RuntimeWarning: invalid value encountered in multiply
#   F_LL = ( ilapse[:,np.newaxis,np.newaxis] * e4phi[:,np.newaxis,np.newaxis] * dAdt_perp
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:178: RuntimeWarning: invalid value encountered in multiply
#   + e4phi[:,np.newaxis,np.newaxis] * (bar_A_LL_A_UL - two_thirds * (bssn_vars.K[:,np.newaxis,np.newaxis] - ilapse[:,np.newaxis,np.newaxis] * div_shift[:,np.newaxis,np.newaxis]) * bar_A_LL))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:197: RuntimeWarning: invalid value encountered in multiply
#   D_L_A_LL = e4phi[:, np.newaxis, np.newaxis, np.newaxis]*(  a_times_d1_s
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:209: RuntimeWarning: overflow encountered in multiply
#   - 4*d2_Lambda_d2_u(lambda_GB)[:,np.newaxis, np.newaxis]* (-(self.v[:,np.newaxis, np.newaxis])*(self.v[:,np.newaxis, np.newaxis]) + np.einsum("xij, xi, xj->x",gamma_UU,self.d1_u,self.d1_u)[:,np.newaxis, np.newaxis])
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:209: RuntimeWarning: invalid value encountered in multiply
#   - 4*d2_Lambda_d2_u(lambda_GB)[:,np.newaxis, np.newaxis]* (-(self.v[:,np.newaxis, np.newaxis])*(self.v[:,np.newaxis, np.newaxis]) + np.einsum("xij, xi, xj->x",gamma_UU,self.d1_u,self.d1_u)[:,np.newaxis, np.newaxis])
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:227: RuntimeWarning: overflow encountered in multiply
#   + 4 * Trace_M * (- d2_Lambda_d2_u(lambda_GB)* (- (self.v)*(self.v) + (np.einsum("xij, xi, xj->x",gamma_UU, self.d1_u, self.d1_u)))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:227: RuntimeWarning: invalid value encountered in multiply
#   + 4 * Trace_M * (- d2_Lambda_d2_u(lambda_GB)* (- (self.v)*(self.v) + (np.einsum("xij, xi, xj->x",gamma_UU, self.d1_u, self.d1_u)))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:261: RuntimeWarning: overflow encountered in multiply
#   scalar_emtensor.rho = (  0.5 * self.v * self.v
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:269: RuntimeWarning: overflow encountered in multiply
#   Vt = - self.v * self.v + em4phi * np.einsum('xij,xi,xj->x', bar_gamma_UU, self.d1_u, self.d1_u)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:273: RuntimeWarning: invalid value encountered in multiply
#   scalar_emtensor.Sij = (scalar_factor[:,np.newaxis,np.newaxis] * bar_gamma_LL
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:295: RuntimeWarning: overflow encountered in multiply
#   dvdt =  (bssn_vars.lapse * bssn_vars.K * self.v
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:174: RuntimeWarning: overflow encountered in multiply
#   diss = sigma * grid.get_kreiss_oliger_diss(unflattened_state)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:175: RuntimeWarning: overflow encountered in multiply
#   rhs_state += sigma * diss
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:175: RuntimeWarning: invalid value encountered in add
#   rhs_state += sigma * diss
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:87: RuntimeWarning: overflow encountered in multiply
#   + e4phi[:, np.newaxis, np.newaxis] *(two_nine * bar_gamma_LL* bssn_vars.K[:, np.newaxis, np.newaxis] * bssn_vars.K[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:88: RuntimeWarning: overflow encountered in multiply
#   + one_third * bssn_vars.K[:, np.newaxis, np.newaxis] * bar_A_LL - AikAjk))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:87: RuntimeWarning: invalid value encountered in subtract
#   + e4phi[:, np.newaxis, np.newaxis] *(two_nine * bar_gamma_LL* bssn_vars.K[:, np.newaxis, np.newaxis] * bssn_vars.K[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:134: RuntimeWarning: overflow encountered in multiply
#   - bssn_vars.K * bssn_vars.K))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:131: RuntimeWarning: invalid value encountered in subtract
#   Line1 = (-four_thirds*Trace_M* (ilapse * dKdt_perp
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:173: RuntimeWarning: overflow encountered in multiply
#   - bssn_vars.K * bssn_vars.K)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:170: RuntimeWarning: invalid value encountered in subtract
#   F = (  ilapse * dKdt_perp
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:178: RuntimeWarning: overflow encountered in multiply
#   + e4phi[:,np.newaxis,np.newaxis] * (bar_A_LL_A_UL - two_thirds * (bssn_vars.K[:,np.newaxis,np.newaxis] - ilapse[:,np.newaxis,np.newaxis] * div_shift[:,np.newaxis,np.newaxis]) * bar_A_LL))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:178: RuntimeWarning: invalid value encountered in subtract
#   + e4phi[:,np.newaxis,np.newaxis] * (bar_A_LL_A_UL - two_thirds * (bssn_vars.K[:,np.newaxis,np.newaxis] - ilapse[:,np.newaxis,np.newaxis] * div_shift[:,np.newaxis,np.newaxis]) * bar_A_LL))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/bssnrhs.py:110: RuntimeWarning: overflow encountered in multiply
#   dKdt = (bssn_vars.lapse * (one_third * bssn_vars.K * bssn_vars.K
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/bssnrhs.py:155: RuntimeWarning: overflow encountered in multiply
#   + bssn_vars.K[:,np.newaxis,np.newaxis] * bssn_vars.a_LL)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/bssnrhs.py:154: RuntimeWarning: invalid value encountered in add
#   + bssn_vars.lapse[:,np.newaxis,np.newaxis] * (- 2.0 * r_AikAkj
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:232: RuntimeWarning: overflow encountered in multiply
#   + 4 * d1_Lambda_d1_u(lambda_GB)*d1_Lambda_d1_u(lambda_GB) * Trace_M * L_GB)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:188: RuntimeWarning: invalid value encountered in add
#   L_GB = Line1 + Line2 + Line3
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:272: RuntimeWarning: divide by zero encountered in divide
#   scalar_factor = - ((0.5 * Vt  + self.V_of_u(self.u)) / em4phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:131: RuntimeWarning: overflow encountered in multiply
#   Line1 = (-four_thirds*Trace_M* (ilapse * dKdt_perp
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:94: RuntimeWarning: invalid value encountered in multiply
#   TraceFree_M_LL = M_LL - one_third * gamma_LL * Trace_M[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/gaussbonnet_working.py:94: RuntimeWarning: invalid value encountered in subtract
#   TraceFree_M_LL = M_LL - one_third * gamma_LL * Trace_M[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:121: RuntimeWarning: invalid value encountered in multiply
#   TraceFree_M_LL = M_LL - one_third * gamma_LL * Trace_M[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:121: RuntimeWarning: invalid value encountered in subtract
#   TraceFree_M_LL = M_LL - one_third * gamma_LL * Trace_M[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:150: RuntimeWarning: overflow encountered in multiply
#   Omega_LL = ( 4 * d1_Lambda_d1_u(lambda_GB)[:,np.newaxis, np.newaxis] * (DiDj_u + e4phi[:,np.newaxis,np.newaxis] * self.v[:,np.newaxis,np.newaxis] * (bar_A_LL + bar_gamma_LL * one_third * bssn_vars.K[:,np.newaxis,np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:162: RuntimeWarning: invalid value encountered in multiply
#   S_GB_L = (Omega_L * Trace_M[:,np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:163: RuntimeWarning: invalid value encountered in multiply
#   + 2*Trace_Omega[:,np.newaxis]*(N_L + one_third * bssn_d1.K)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:184: RuntimeWarning: invalid value encountered in multiply
#   TraceFree_Omega_LL = Omega_LL - one_third * gamma_LL * Trace_Omega[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:184: RuntimeWarning: invalid value encountered in subtract
#   TraceFree_Omega_LL = Omega_LL - one_third * gamma_LL * Trace_Omega[:, np.newaxis, np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:211: RuntimeWarning: invalid value encountered in multiply
#   - two_thirds * Trace_Omega[:,np.newaxis, np.newaxis]*(F_LL - one_third * gamma_LL*(ilapse[:,np.newaxis, np.newaxis] * D2_lapse[:,np.newaxis, np.newaxis] - Asquared[:,np.newaxis, np.newaxis]))
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:226: RuntimeWarning: invalid value encountered in add
#   S_GB = (  four_thirds * Trace_Omega * F
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:272: RuntimeWarning: overflow encountered in divide
#   scalar_factor = - ((0.5 * Vt  + self.V_of_u(self.u)) / em4phi)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:162: RuntimeWarning: overflow encountered in multiply
#   S_GB_L = (Omega_L * Trace_M[:,np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:162: RuntimeWarning: invalid value encountered in subtract
#   S_GB_L = (Omega_L * Trace_M[:,np.newaxis]
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/matter/scalarmatter.py:216: RuntimeWarning: invalid value encountered in add
#   + 2 * (  np.einsum("xik, xck, xjc->xij",TraceFree_Omega_LL, gamma_UU, F_LL)
# /Users/serdaryildiz/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:64: RuntimeWarning: divide by zero encountered in power
#   rescaling_factor = np.power(determinant_bar_gamma / determinant_hat_gamma, -1./3)
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[22], line 15
#      11 # Solve for the solution using RK45 integration of the ODE
#      12 # to make like (older) python odeint method use method='LSODA' instead
#      13 # use tqdm package to track progress
#      14 with tqdm(total=1000, unit="‰") as progress_bar:
# ---> 15     dense_solution = solve_ivp(get_rhs, [0,T], initial_state,
#      16                                args=(grid, background, my_matter, progress_bar, [0, T/1000]),
#      17                         #atol=1e-5, rtol=1e-5,
#      18                         max_step = 0.4 * min_dr, #for stability and for KO coeff of 1
#      19                         method='RK45', dense_output=True)
#      21 # Interpolate the solution at the time points requested
#      22 solution = dense_solution.sol(t).T
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/ivp.py:650, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     648 status = None
#     649 while status is None:
# --> 650     message = solver.step()
#     652     if solver.status == 'finished':
#     653         status = 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/rk.py:67, in rk_step(fun, t, y, f, h, A, B, C, K)
#      64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
# ---> 67 f_new = fun(t + h, y_new)
#      69 K[-1] = f_new
#      71 return y_new, f_new
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# File ~/Library/Python/3.9/lib/python/site-packages/scipy/integrate/_ivp/ivp.py:588, in solve_ivp.<locals>.fun(t, x, fun)
#     587 def fun(t, x, fun=fun):
# --> 588     return fun(t, x, *args)
#
# File ~/Desktop/GRSerdar/engrenage/SGB_BR/source/core/rhsevolution.py:75, in get_rhs(t_i, current_state, grid, background, matter, progress_bar, time_state)
#      73 em4phi = np.exp(-4.0*bssn_vars.phi)
#      74 bar_gamma_LL = get_bar_gamma_LL(r, bssn_vars.h_LL, background)
# ---> 75 bar_gamma_UU = get_bar_gamma_UU(r, bssn_vars.h_LL, background)
#      76 gamma_UU = em4phi[:,np.newaxis,np.newaxis] *bar_gamma_UU
#      78 new_bar_gamma_LL = rescaling_factor[:,np.newaxis,np.newaxis] * bar_gamma_LL
#
# File ~/Desktop/GRSerdar/engrenage/SGB_BR/source/bssn/tensoralgebra.py:116, in get_bar_gamma_UU(r, h_LL, background)
#     112 def get_bar_gamma_UU(r, h_LL, background):
#     114     bar_gamma_LL = get_bar_gamma_LL(r, h_LL, background)
# --> 116     return np.linalg.inv(bar_gamma_LL)
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/linalg/linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/linalg/linalg.py:112, in _raise_linalgerror_singular(err, flag)
#     111 def _raise_linalgerror_singular(err, flag):
# --> 112     raise LinAlgError("Singular matrix")
#
# LinAlgError: Singular matrix

# %% [markdown]
# # Evolution of scalar field

# %%
inta = 0
for i in range(len(my_state_vector.VARIABLE_NAMES)):
    print('Index: ', inta, 'Variable Name: ',  my_state_vector.VARIABLE_NAMES[i])
    inta = inta +1
# Out:
# Index:  0 Variable Name:  phi
# Index:  1 Variable Name:  hrr
# Index:  2 Variable Name:  htt
# Index:  3 Variable Name:  hpp
# Index:  4 Variable Name:  K
# Index:  5 Variable Name:  arr
# Index:  6 Variable Name:  att
# Index:  7 Variable Name:  app
# Index:  8 Variable Name:  lambdar
# Index:  9 Variable Name:  shiftr
# Index:  10 Variable Name:  br
# Index:  11 Variable Name:  lapse
# Index:  12 Variable Name:  u
# Index:  13 Variable Name:  v

# %%
# Plot a single point versus time
idx_u = 12

var1 = idx_u

idx = NUM_GHOSTS + 2 # Choose an inner point
r_i = np.round(r[idx],2)
var1_of_t = solution[:, var1 * num_points + idx]
plt.plot(t, var1_of_t, 'b-', label=my_state_vector.VARIABLE_NAMES[var1])

"""
var2_of_t = solution[:, var2 * num_points + idx]
plt.plot(t, var2_of_t, 'g-', label=my_state_vector.VARIABLE_NAMES[var2])


var3_of_t = solution[:, var3 * num_points + idx]
plt.plot(t, var3_of_t, 'g-', label=my_state_vector.VARIABLE_NAMES[var3])'''
"""
plt.legend(loc='best')
plt.title("Value of scalar field at r")
plt.xlabel('t')
plt.ylabel('value at r is '+str(r_i))
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# # Evolution of variables (lapse, shift, K, Conformal factor, ...)

# %%
# Plot a single point versus time
idx_u = 11

var1 = 11

idx = NUM_GHOSTS + 2 # Choose an inner point
r_i = np.round(r[idx],2)
var1_of_t = solution[:, var1 * num_points + idx]
plt.plot(t, var1_of_t, 'b-', label=my_state_vector.VARIABLE_NAMES[var1])

"""
var2_of_t = solution[:, var2 * num_points + idx]
plt.plot(t, var2_of_t, 'g-', label=my_state_vector.VARIABLE_NAMES[var2])


var3_of_t = solution[:, var3 * num_points + idx]
plt.plot(t, var3_of_t, 'g-', label=my_state_vector.VARIABLE_NAMES[var3])'''
"""
plt.legend(loc='best')
plt.xlabel('t')
plt.ylabel('value at r is '+str(r_i))
plt.legend(loc='best')
plt.grid()

# %%
# Plot a single point versus time
idx_u = 11

var1 = 9

idx = NUM_GHOSTS + 2 # Choose an inner point
r_i = np.round(r[idx],2)
var1_of_t = solution[:, var1 * num_points + idx]
plt.plot(t, var1_of_t, 'b-', label=my_state_vector.VARIABLE_NAMES[var1])

"""
var2_of_t = solution[:, var2 * num_points + idx]
plt.plot(t, var2_of_t, 'g-', label=my_state_vector.VARIABLE_NAMES[var2])


var3_of_t = solution[:, var3 * num_points + idx]
plt.plot(t, var3_of_t, 'g-', label=my_state_vector.VARIABLE_NAMES[var3])'''
"""
plt.legend(loc='best')
plt.xlabel('t')
plt.ylabel('value at r is '+str(r_i))
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# ## Different variables at different radii and different times

# %% [markdown]
# ## Conformal factor

# %%
# i is the index of time 
# t_i is the corresponding timie value to that index

# if (i < 1000) and (i % 10 == 0) and (t_i > 9.0):
    # i< 100: times before the 100the time point (only the index of the time)
    # (i % 10 == 0) : every 10th point, avoids to many lines.
    # (t_i > 9.0) : the actual value of the time must be greater than 9 


iii = 10
var = 12
for i, t_i in enumerate(t) :
    if (25<t_i < 45) and (i % 10 == 0) :
        labelt = "t="+str(round(t_i,2))
        f_t = solution[i, var * num_points: (var + 1) * num_points]
        plt.plot(r, f_t, label=labelt)

plt.legend(loc=4)
plt.xlabel('r')
plt.ylabel('value over time of ' + my_state_vector.VARIABLE_NAMES[var])

ax = plt.gcf().gca()
set_grid_on_ax(ax, r)
plt.xlim(-1,25)
plt.ylim(-0.01,0.16)
# Out:
# (-0.01, 0.16)

# %% [markdown]
# # Evolution of different parameters in function of $r$ at $t=0$

# %%
# i is the index of time 
# t_i is the corresponding timie value to that index

# if (i < 1000) and (i % 10 == 0) and (t_i > 9.0):
    # i< 100: times before the 100the time point (only the index of the time)
    # (i % 10 == 0) : every 10th point, avoids to many lines.
    # (t_i > 9.0) : the actual value of the time must be greater than 9 


iii = 10
var = 12
for i, t_i in enumerate(t) :
    if (i < 40) and (i % 10 == 0) and (t_i > 1.0):
        labelt = "t="+str(round(t_i,2))
        f_t = solution[i, var * num_points: (var + 1) * num_points]
        print('Actual AH: ', ah_radius[0])
        print('Effective AH: ', r[iii])
        print('phi at AH: ', f_t[iii])
        print('chi0: ',np.exp(-4*f_t[iii]))
        plt.plot(r, f_t, label=labelt)

plt.legend(loc=4)
plt.xlabel('r')
plt.ylabel('value over time of ' + my_state_vector.VARIABLE_NAMES[var])

ax = plt.gcf().gca()
set_grid_on_ax(ax, r)
plt.xlim(-0.2,5)
plt.ylim(0,0.1)
# Out:
# Actual AH:  0.498678538330956
# Effective AH:  0.47993604100070275
# phi at AH:  0.00987066070511328
# chi0:  0.9612866390705852
# Actual AH:  0.498678538330956
# Effective AH:  0.47993604100070275
# phi at AH:  0.08294035180617568
# chi0:  0.7176585305696935
# Actual AH:  0.498678538330956
# Effective AH:  0.47993604100070275
# phi at AH:  0.09060490197558506
# chi0:  0.6959902635468855
# (0.0, 0.1)

# %% [markdown]
# ## Scalar Field

# %%
# i is the index of time 
# t_i is the corresponding timie value to that index

# if (i < 1000) and (i % 10 == 0) and (t_i > 9.0):
    # i< 100: times before the 100the time point (only the index of the time)
    # (i % 10 == 0) : every 10th point, avoids to many lines.
    # (t_i > 9.0) : the actual value of the time must be greater than 9 



var = 12
for i, t_i in enumerate(t) :
    if (i < 50) and (i % 1 == 0) and (t_i > 5.0):
        labelt = "t="+str(round(t_i,2))
        f_t = solution[i, var * num_points: (var + 1) * num_points]
        plt.plot(r, f_t, label=labelt)

plt.legend(loc=4)
plt.xlabel('r')
plt.ylabel('value over time of ' + my_state_vector.VARIABLE_NAMES[var])

ax = plt.gcf().gca()
set_grid_on_ax(ax, r)
plt.xlim(-1,3)
plt.ylim(-1,2)
# Out:
# (-1.0, 2.0)

# %%
'''# calculate the diagnostics, just the Hamiltonian constraint for now
Ham, Mom = get_constraints_diagnostic(solution, t, grid, background, my_matter)'''
# Out:
# '# calculate the diagnostics, just the Hamiltonian constraint for now\nHam, Mom = get_constraints_diagnostic(solution, t, grid, background, my_matter)'

# %%
'''# plot the profile for Ham and Mom at a selection of times

for i, t_i in enumerate(t) :
    if (i < num_points_t) and (i % 30 == 0) :
        labelt = "t="+str(round(t_i,2))
        Ham_t = Ham[i,:]
        ax1 = plt.subplot(211)
        plt.plot(r, Ham_t, label=labelt)
        ax2 = plt.subplot(212)
        Mom_t = np.sqrt(Mom[i,:,i_r]**2 + Mom[i,:,i_t]**2 + Mom[i,:,i_p]**2)
        plt.plot(r, Mom_t, label=labelt)

plt.legend()
ax2.set_xlabel('r')
ax1.set_ylabel('Ham value over time')
ax1.set_xlim(-1,20.0)
ax1.set_ylim(-0.1,0.1)
ax1.grid()
ax2.set_ylabel('Mom_r value over time')
ax2.set_xlim(-1,20.0)
ax2.set_ylim(-0.1,0.1)
ax2.grid()'''
# Out:
# '# plot the profile for Ham and Mom at a selection of times\n\nfor i, t_i in enumerate(t) :\n    if (i < num_points_t) and (i % 30 == 0) :\n        labelt = "t="+str(round(t_i,2))\n        Ham_t = Ham[i,:]\n        ax1 = plt.subplot(211)\n        plt.plot(r, Ham_t, label=labelt)\n        ax2 = plt.subplot(212)\n        Mom_t = np.sqrt(Mom[i,:,i_r]**2 + Mom[i,:,i_t]**2 + Mom[i,:,i_p]**2)\n        plt.plot(r, Mom_t, label=labelt)\n\nplt.legend()\nax2.set_xlabel(\'r\')\nax1.set_ylabel(\'Ham value over time\')\nax1.set_xlim(-1,20.0)\nax1.set_ylim(-0.1,0.1)\nax1.grid()\nax2.set_ylabel(\'Mom_r value over time\')\nax2.set_xlim(-1,20.0)\nax2.set_ylim(-0.1,0.1)\nax2.grid()'

# %% [markdown]
# # AH finder

# %%
# Track the BH mass, show constant despite gauge evolution
omega, ah_radius, bh_mass = get_horizon_diagnostics(solution, t, grid, background, my_matter)

plt.plot(t, bh_mass, 'b-', label="AH Mass")
plt.plot(t, ah_radius, 'g--', label="AH Radius")
plt.legend(loc='best')
plt.xlabel('t')
plt.ylabel('BH mass')
plt.legend(loc='best')
#plt.ylim(-0.1,1.3)

#print('t: ', t)
#print('R_{AH}: ', ah_radius)
#print(len(ah_radius))


plt.grid()

# %% [markdown]
# # Scalar field evolution at AH

# %%
interpolated_u_of_r_at_different_times = []
var = 12

for timepoint in range(len(t)):
    interpolated_u_of_r_at_different_times.append(interp1d(r,solution[timepoint, var * num_points: (var + 1) * num_points],  kind='cubic'))
    


u_of_ahR = []

for idx_ahr, ahr in enumerate(ah_radius):
    u_of_ahR.append(interpolated_u_of_r_at_different_times[idx_ahr](ahr))


var = 12

#print(u_of_ahR)

# %%
maxidx = 249

'''
tester = []
for i in range(len(u_of_ahR[:maxidx])):
    tester.append(3*np.pi*u_of_ahR[:maxidx][i])
'''

plt.plot(t[:maxidx], u_of_ahR[:maxidx], 'b-', label=r'$\phi$', linewidth=2)
#plt.plot(t[:maxidx], tester, 'b-', label='u')

plt.legend(loc='best')
plt.ylim(-0.01,0.11)
plt.xlim(-5,100)
plt.xlabel(r'$t/M$', fontsize=14)
plt.ylabel(r'$\langle \phi \rangle_{AH}$', fontsize=14)
plt.legend(loc='best')
plt.grid()

print('final value of scalar field: ', u_of_ahR[maxidx])
#plt.savefig('ScalarProfile')
# Out:
# final value of scalar field:  0.05921983458644154

# %%
maxidx = 249

'''
tester = []
for i in range(len(u_of_ahR[:maxidx])):
    tester.append(3*np.pi*u_of_ahR[:maxidx][i])
'''

plt.plot(t[:maxidx], u_of_ahR[:maxidx], 'b-', label=r'$\phi$', linewidth=2)
#plt.plot(t[:maxidx], tester, 'b-', label='u')

plt.legend(loc='best')
plt.ylim(-0.01,0.21)
plt.xlim(-5,100)
plt.xlabel(r'$t/M$', fontsize=14)
plt.ylabel(r'$\langle \phi \rangle_{AH}$', fontsize=14)
plt.legend(loc='best')
plt.grid()

print('final value of scalar field: ', u_of_ahR[maxidx])
#plt.savefig('ScalarProfile')
# Out:
# final value of scalar field:  0.05921983458644154

# %% [markdown]
# ###

# %% [markdown]
# ### Higher quality

# %%
import matplotlib.pyplot as plt
import numpy as np

maxidx = 249  # will plot indices [0..248]; last plotted point is maxidx-1

plt.rcParams.update({
    "figure.dpi": 150,        # on-screen sharpness
    "savefig.dpi": 300,       # export resolution for PNG
    "axes.labelsize": 16,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

fig, ax = plt.subplots(figsize=(7.5, 5), constrained_layout=True)  # bigger canvas
ax.plot(t[:maxidx], u_of_ahR[:maxidx], 'b-', lw=2.5, label=r'$\phi$')

ax.set_xlim(-5, 100)
ax.set_ylim(-0.01, 0.11)
ax.set_xlabel(r'$t/M$')
ax.set_ylabel(r'$\langle \phi \rangle_{AH}$')
ax.legend(frameon=False, loc='best')
ax.grid(True, alpha=0.3)
ax.tick_params(width=1.2, length=6)
for s in ax.spines.values():
    s.set_linewidth(1.2)

print('final value of scalar field (last plotted point):', u_of_ahR[maxidx-1])

# High-quality exports:
#fig.savefig('ScalarProfile.pdf', bbox_inches='tight')   # vector, infinite zoom
#fig.savefig('ScalarProfile.png', dpi=300, bbox_inches='tight')  # crisp raster
# fig.savefig('ScalarProfile.svg', bbox_inches='tight')  # alternative vector
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 16
#       6 plt.rcParams.update({
#       7     "figure.dpi": 150,        # on-screen sharpness
#       8     "savefig.dpi": 300,       # export resolution for PNG
#    (...)
#      12     "legend.fontsize": 12,
#      13 })
#      15 fig, ax = plt.subplots(figsize=(7.5, 5), constrained_layout=True)  # bigger canvas
# ---> 16 ax.plot(t[:maxidx], u_of_ahR[:maxidx], 'b-', lw=2.5, label=r'$\phi$')
#      18 ax.set_xlim(-5, 100)
#      19 ax.set_ylim(-0.01, 0.11)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_axes.py:1724, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1481 """
#    1482 Plot y versus x as lines and/or markers.
#    1483
#    (...)
#    1721 (``'green'``) or hex strings (``'#008000'``).
#    1722 """
#    1723 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1724 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1725 for line in lines:
#    1726     self.add_line(line)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py:303, in _process_plot_var_args.__call__(self, axes, data, *args, **kwargs)
#     301     this += args[0],
#     302     args = args[1:]
# --> 303 yield from self._plot_args(
#     304     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/axes/_base.py:499, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     496     axes.yaxis.update_units(y)
#     498 if x.shape[0] != y.shape[0]:
# --> 499     raise ValueError(f"x and y must have same first dimension, but "
#     500                      f"have shapes {x.shape} and {y.shape}")
#     501 if x.ndim > 2 or y.ndim > 2:
#     502     raise ValueError(f"x and y can be no greater than 2D, but have "
#     503                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (249,) and (1,)

# %% [markdown]
# #
# #

# %% [markdown]
# # Conformal factor at apparant horizon

# %%
var0 = 0

interpolated_phi_of_r_at_different_times = []

for timepoint in range(len(t)):
    interpolated_phi_of_r_at_different_times.append(interp1d(r,solution[timepoint, var0 * num_points: (var0 + 1) * num_points],  kind='quadratic', fill_value='extrapolate'))
    
# This is a list of all of the interpolation functions (function of value of u in terms value of r [gotten in an interpolated way]) at all the different time steps

# %%
phi_of_ahR = []

for idx_ahr, ahr in enumerate(ah_radius):
    phi_of_ahR.append(interpolated_phi_of_r_at_different_times[idx_ahr](ahr))
    
#print(u_of_ahR)

# %%
maxidx = 249

def chicalc(phi):
    return np.exp(-4*phi)

listofchi = []
for i in range(len(phi_of_ahR)):
    listofchi.append(chicalc(phi_of_ahR[i]))

plt.plot(t[:maxidx], listofchi[:maxidx], 'b-', label='chi')
plt.legend(loc='best')
plt.xlabel('t')
plt.ylabel('$\chi_{AH}$')
plt.legend(loc='best')
plt.grid()

print('initial value of chi: ', listofchi[maxidx])
# Out:
# initial value of chi:  0.218410719776128

# %% [markdown]
# # Coupling function analysis

# %%
chi = np.linspace(0, 1, 1000)
chi0 = 0.15

def function_of_lambda(chi0, lambda_GB):
    return (lambda_GB)/(1+np.exp(-100*(chi-chi0)))

plt.plot(chi, function_of_lambda(chi0, 0.05))
plt.axvline(x=listofchi[maxidx], color='r', linestyle='--', label='MaxChi')

plt.grid()
plt.xlim(0,0.3)
# Out:
# (0.0, 0.3)
